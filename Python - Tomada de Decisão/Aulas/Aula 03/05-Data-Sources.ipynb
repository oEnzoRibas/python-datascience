# %% [markdown]
# ### IMPORTANT NOTE: Your internet service provider or network admin or firewall may block you from directly reading information from outside sources. Please keep this in mind if you get errors. Also note, APIs change often, make sure to do your best independent research to explore current best options, as the code seen here may change.

# %% [markdown]
# ## Pandas DataReader
#
# Make sure to check the latest examples and notification of API changes here:
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#remote-data-wb

# %% [markdown]
# #### General Stock Data from Yahoo (not official API)

# %%
import os
#import pandas_datareader as webreader
import pandas_datareader.data as web
import pandas as pd
import datetime as dt
from pandas_datareader import data as pdr
import yfinance as yfin
yfin.pdr_override()
#from datetime import datetime

# %%
#start = datetime.datetime(2020, 1, 1)
#end = datetime.datetime(2021, 1, 1)

#df=web.DataReader('GE', 'yahoo', start='2019-09-10', end='2019-10-09')
                  
aapl_df = pdr.get_data_yahoo('AAPL', start='2019-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
aapl_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  37.943260  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.163826  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.622261  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.542976  219111200
# 2019-01-08  37.389999  37.955002  37.130001  37.687500  36.220520  164101200

# %% [markdown]
# # FRED
#
# https://fred.stlouisfed.org/
#
# 10-Year Breakeven Inflation Rate (T10YIE)
#
# https://fred.stlouisfed.org/series/T10YIE

# %%
import pandas_datareader.data as web

# %%
inflation_df = ('T10YIE','fred', start == '2004-01-01',end == '2020-01-01')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 inflation_df = ('T10YIE','fred', start == '2004-01-01',end == '2020-01-01')
#
# NameError: name 'start' is not defined

# %%
ty_inflation_df = web.DataReader('T10YIE', 'fred', 
                                 start='2004-01-01',end='2021-01-01')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ty_inflation_df = web.DataReader('T10YIE', 'fred',
#       2                                  start='2004-01-01',end='2021-01-01')
#
# File ~/anaconda3/lib/python3.11/site-packages/yfinance/utils.py:114, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     111 logger.debug(f'Entering {func.__name__}()')
#     113 with IndentationContext():
# --> 114     result = func(*args, **kwargs)
#     116 logger.debug(f'Exiting {func.__name__}()')
#     117 return result
#
# TypeError: download() got multiple values for argument 'start'

# %%
inflation_df=pdr.get_data_fred('T10YIE', start='2004-01-01',end='2021-01-01')

# %%
inflation_df.tail()
# Out:
#             T10YIE
# DATE
# 2020-12-28    1.97
# 2020-12-29    1.96
# 2020-12-30    1.96
# 2020-12-31    1.99
# 2021-01-01     NaN

# %%
inflation_df.plot()
# Out:
# /home/fischer/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1732: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   ret = self.converter.convert(x, self.units, self)
# /home/fischer/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1732: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# /home/fischer/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1484: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return self.major.locator()
# /home/fischer/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1484: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
# ...

# %% [markdown]
# ### Yahoo Finance yfinance (unofficial API)

# %%
#import yfinance as yf

# %%
apple= yfin.download("AAPL",start='2020-01-01',end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   73.249016
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   72.536888
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   73.114891
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   72.771034
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   73.941643
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.850555
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.494781
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.703995
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.572479
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.559021
#
#                Volume
# Date
# 2020-01-02  135480400
# 2020-01-03  146322800
# 2020-01-06  118387200
# ...

# %% [markdown]
# ### General Information

# %%
apple_ticker = yfin.Ticker('AAPL')

# %%
apple_ticker.financials
# Out:
#                                                         2022-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.162045
# Normalized EBITDA                                   130541000000.0
# Net Income From Continuing Operation Net Minori...   99803000000.0
# Reconciled Depreciation                              11104000000.0
# Reconciled Cost Of Revenue                          223546000000.0
# EBITDA                                              130541000000.0
# EBIT                                                119437000000.0
# Net Interest Income                                   -106000000.0
# Interest Expense                                      2931000000.0
# Interest Income                                       2825000000.0
# Normalized Income                                    99803000000.0
# Net Income From Continuing And Discontinued Ope...   99803000000.0
# ...

# %%
apple_ticker.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-05-11 00:00:00-04:00   0.000536           0.0
# 1987-06-16 00:00:00-04:00   0.000000           2.0
# 1987-08-10 00:00:00-04:00   0.000536           0.0
# 1987-11-17 00:00:00-05:00   0.000714           0.0
# 1988-02-12 00:00:00-05:00   0.000714           0.0
# ...                              ...           ...
# 2022-08-05 00:00:00-04:00   0.230000           0.0
# 2022-11-04 00:00:00-04:00   0.230000           0.0
# 2023-02-10 00:00:00-05:00   0.230000           0.0
# 2023-05-12 00:00:00-04:00   0.240000           0.0
# 2023-08-11 00:00:00-04:00   0.240000           0.0
#
# [85 rows x 2 columns]

# %%
apple_ticker.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2022-08-05 00:00:00-04:00    0.230000
# 2022-11-04 00:00:00-04:00    0.230000
# 2023-02-10 00:00:00-05:00    0.230000
# 2023-05-12 00:00:00-04:00    0.240000
# 2023-08-11 00:00:00-04:00    0.240000
# Name: Dividends, Length: 80, dtype: float64

# %%
apple= yfin.download("AAPL",start='2020-01-01',end='2021-01-01')
